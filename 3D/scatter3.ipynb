# %% [markdown]
# # <img style='float: left' src="http://lightning-viz.github.io/images/logo.png"> <br> <br> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;3D scatter plots in <a href='http://lightning-viz.github.io/'><font color='#9175f0'>Lightning</font></a>

# %% [markdown]
# ## <hr> Setup

# %%
from lightning import Lightning

from numpy import random, asarray, amin, concatenate, column_stack 
from seaborn import color_palette
from sklearn import datasets

# %% [markdown]
# ## Connect to server

# %%
lgn = Lightning(ipython=True)
# Out:
# <div style='margin-top:8px'><img src='data:image/png;base64,...' width='30px' height='35px' style='display: inline-block; padding-right: 10px'></img><span>Lightning initialized</span></div>
# Connected to server at http://localhost:3000

# %% [markdown]
# ## <hr> Random points with default styling

# %%
n = 100
x = random.rand(n)*100
y = random.rand(n)*100
z = random.rand(n)*100

lgn.scatter3(x,y,z)
# Out:
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/><meta http-equiv="X-UA-Compatible" content="IE=10; IE=9; IE=8; IE=7; IE=EDGE"/><meta charset="UTF-8"/><link href="//fonts.googleapis.com/css?family=Open+Sans:400,700" rel="stylesheet" type="text/css"/><link rel="stylesheet" href="http://localhost:3000/css/app.css"/><link rel="stylesheet" href="http://localhost:3000/css/dynamic/viz/?visualizations[]=scatter-3"/><div id="lightning-body" class="container content wrap push"><div class="feed-container"><div data-model="visualization" data-model-id="b6d86679-babe-474b-ba28-eb06608be50a" class="feed-item-container"><div data-type="lightning-scatter-3" data-data="{&quot;points&quot;:[[63.441456136537134,14.820954798601448,24.121180583004985],[90.9094944344339,98.67262838835413,23.023600129599796],[22.06153314624235,7.792753402593899,49.81856595391978],[26.37754948779922,83.43603259002296,7.07932183524399],[92.65718870104368,62.49490427801714,91.485639771540
# ...

# %% [markdown]
# ## <hr> Random small red points

# %%
n = 100
x = random.rand(n)*100
y = random.rand(n)*100
z = random.rand(n)*100
c = [240,117,145]

lgn.scatter3(x,y,z,size=4,color=c)
# Out:
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/><meta http-equiv="X-UA-Compatible" content="IE=10; IE=9; IE=8; IE=7; IE=EDGE"/><meta charset="UTF-8"/><link href="//fonts.googleapis.com/css?family=Open+Sans:400,700" rel="stylesheet" type="text/css"/><link rel="stylesheet" href="http://localhost:3000/css/app.css"/><link rel="stylesheet" href="http://localhost:3000/css/dynamic/viz/?visualizations[]=scatter-3"/><div id="lightning-body" class="container content wrap push"><div class="feed-container"><div data-model="visualization" data-model-id="008bbd37-677c-45da-b3bc-9f9f8c0936e6" class="feed-item-container"><div data-type="lightning-scatter-3" data-data="{&quot;color&quot;:[[240,117,145]],&quot;points&quot;:[[69.59699035099044,71.14700849375009,33.44532564796293],[44.87278041634958,27.687549686963308,1.4246476586578738],[66.66649317398455,30.935505740093017,46.15074457084592],[34.30094557638941,13.54473224071896,59.727882097145844],[85.065053400233
# ...

# %% [markdown]
# ## <hr> Random points with all styling options

# %%
n = 100
x = random.rand(n)*100
y = random.rand(n)*100
z = random.rand(n)*100
c = [asarray(color_palette('Blues', 100)[random.choice(range(100))])*255 for i in range(n)]
s = random.rand(n)*8+1

lgn.scatter3(x, y, z, color=c, size=s)
# Out:
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/><meta http-equiv="X-UA-Compatible" content="IE=10; IE=9; IE=8; IE=7; IE=EDGE"/><meta charset="UTF-8"/><link href="//fonts.googleapis.com/css?family=Open+Sans:400,700" rel="stylesheet" type="text/css"/><link rel="stylesheet" href="http://localhost:3000/css/app.css"/><link rel="stylesheet" href="http://localhost:3000/css/dynamic/viz/?visualizations[]=scatter-3"/><div id="lightning-body" class="container content wrap push"><div class="feed-container"><div data-model="visualization" data-model-id="711ab68b-7c5c-4f15-86bd-5fe99672cd2f" class="feed-item-container"><div data-type="lightning-scatter-3" data-data="{&quot;color&quot;:[[221.9058843255043,234.93725609779358,246.9686279296875],[235.23529529571533,243.4705889225006,251.23529434204102],[85.77647307515144,159.5058880448341,205.71764999628067],[47.75294382870198,127.75294455885886,188.6000039577484],[213.62353187799454,229.41568779945374,244.2078437
# ...

# %% [markdown]
# ## <hr> Fun with colors

# %%
n = 500
x = random.rand(n)*255
y = random.rand(n)*255
z = random.rand(n)*255
c = column_stack((x,y,z))

lgn.scatter3(x,y,z,color=c, size=3)
# Out:
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/><meta http-equiv="X-UA-Compatible" content="IE=10; IE=9; IE=8; IE=7; IE=EDGE"/><meta charset="UTF-8"/><link href="//fonts.googleapis.com/css?family=Open+Sans:400,700" rel="stylesheet" type="text/css"/><link rel="stylesheet" href="http://localhost:3000/css/app.css"/><link rel="stylesheet" href="http://localhost:3000/css/dynamic/viz/?visualizations[]=scatter-3"/><div id="lightning-body" class="container content wrap push"><div class="feed-container"><div data-model="visualization" data-model-id="444fd6d0-4eb3-4322-8fbb-c435d8943ca1" class="feed-item-container"><div data-type="lightning-scatter-3" data-data="{&quot;color&quot;:[[177.1589774494148,50.42583153148224,167.1914226055474],[79.26785675966599,149.84975846213152,7.433225953684297],[129.95196299502257,85.76002996290178,19.22140351412738],[78.1103599658843,235.9723007352059,159.97826447458678],[102.4962428079444,82.97839915069414,184.387151713641
# ...
